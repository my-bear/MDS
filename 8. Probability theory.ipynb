# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm, t
import math
from pylab import rcParams
rcParams['figure.figsize'] = 13,6

# %% [markdown]
# #### Задание 1.
# Получить интуицию, на что влияют параметры распределений. Построить по 5 функций плотностей с разными параметрами для каждого распределения: нормальное, экспоненциальное, Стьюдента на одном графике.

# %%
x = np.linspace(-4, 6, 100)
mu = (-1, 0, 1, 1, 2)
sigma = (0.6, 1, 1.5, 1.75, 2)

plt.plot(x, norm.pdf(x, mu[0], sigma[0]))
plt.plot(x, norm.pdf(x, mu[1], sigma[1]))
plt.plot(x, norm.pdf(x, mu[2], sigma[2]))
plt.plot(x, norm.pdf(x, mu[3], sigma[3]))
plt.plot(x, norm.pdf(x, mu[4], sigma[4]))

plt.title('Normal Distributions')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.show()

# %%
lambd = (0.5, 1, 1.2, 2, 3)

x = np.arange(0, 8, 0.1)

y_0 = lambd[0] * np.exp(-lambd[0] * x)
y_1 = lambd[1] * np.exp(-lambd[1] * x)
y_2 = lambd[2] * np.exp(-lambd[2] * x)
y_3 = lambd[3] * np.exp(-lambd[3] * x)
y_4 = lambd[4] * np.exp(-lambd[4] * x)

plt.plot(x, y_0)
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)
plt.plot(x, y_4)

plt.title('Exponential Distributions')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.show()

# %%
x = np.linspace(rv.ppf(0.00001), rv.ppf(0.99999999), 100)

rv_1 = t(df=30, loc=0, scale=1)
y_1 = rv_1.pdf(x)

rv_2 = t(df=25, loc=1, scale=1)
y_2 = rv_2.pdf(x)

rv_3 = t(df=20, loc=-1, scale=1)
y_3 = rv_3.pdf(x)

rv_4 = t(df=15, loc=2, scale=1)
y_4 = rv_4.pdf(x)

rv_5 = t(df=10, loc=3, scale=1)
y_5 = rv_5.pdf(x)


plt.plot(x,y_1)
plt.plot(x,y_2)
plt.plot(x,y_3)
plt.plot(x,y_4)
plt.plot(x,y_5)

plt.title('Student t-Distributions')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.show()

# %% [markdown]
# #### Задание 2.
# Непрерывная случайная величина задана плотностью распределения:
# $ f(\xi) = C, \xi \in [0;5];f(\xi) = 0, \xi \notin  [0;5]$
# Найдите C, математическое ожидание $\xi$, а также вероятность попадания в отрезок $[3.5;7]$, т.е. P(3.5 < $\xi$ < 7).

# %% [markdown]
# С = 1/(b - a) = 1/(5-0)= 1/5
#
# E = (a+b)/2 = (0+5)/2 = 2.5
#
# P(3.5 < E < 7) = 1.5 * 1/5 = 0.3

# %% [markdown]
# #### Задание 3.
# Известно, что светофор горит 54 секунды красным, 4 секунды жёлтым и 28 секунд зелёным. Посчитайте, какое количество информации несёт сообщение о цвете светофора в текущий момент. А что будет в случае 28, 28 и 28 секунд для каждого цвета?

# %%
p_red = 54/(54+4+28)
p_orange = 4/(54+4+28)
p_green = 28/(54+4+28)

I_red = math.log2(1/p_red)
I_orange = math.log2(1/p_orange)
I_green = math.log2(1/p_green)

print(I_red, I_orange, I_green)
# Out:
# 0.6713772525386293 4.426264754702098 1.6189098326444937

# %%
p_red = 28/(28*3)
p_orange = 28/(28*3)
p_green = 28/(28*3)

I_red = math.log2(1/p_red)
I_orange = math.log2(1/p_orange)
I_green = math.log2(1/p_green)

print(I_red, I_orange, I_green)
# Out:
# 1.584962500721156 1.584962500721156 1.584962500721156
